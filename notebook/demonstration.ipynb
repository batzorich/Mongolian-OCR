# %%
import cv2
from src.service import extract_text

IMAGE_PATH = "test_imgs/img_001.jpg"
img = cv2.imread(IMAGE_PATH, cv2.IMREAD_COLOR)
result = extract_text(img)
# Out:
# 2025-04-10 12:36:55.471346: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-10 12:36:55.472046: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-10 12:36:55.475304: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-10 12:36:55.483516: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744277815.495895  225924 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744277815.499378  225924 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-10 12:36:55.513210: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-10 12:36:57.081469: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
print(result)
# Out:
# 4.2.Төрийн болон орон нутгийн өмчийн орон сууцны санг бүрдүүлж, тэргүүн
# ээлжид орон байргүй хөгжлийн бэрхшээлтэй гишүүнтэй өрхөд хөлслүүлэх,
# эзэмшүүлэх, төлбөрийн уян хатан, хөнгөлөлттэй нөхцөлөөр худалдан авах боломж
# бүрдүүлэх эорилтын хүрээнд дараах үйл ажиллагааг хэрэгжүүлнэ:
# 4.2.1.аймаг, нийслэлийн 3асаг дарга нь орон сууц барих аж ахуйн
# нэгжтэй тохиролцон шинээр баригдах орон сууцны газар, дэд бүтцэд улс, орон
# нутгийн төсвөөс оруулсан хөрөнгө оруулалттай дүйцүүлэн, тодорхой хувьд ны орон
# сууцыг гэрээний дагуу эээмшилдээ авах замаар орон нуттийн түрээсийв орон
# сууцны санг бүрдүүлэх, нэмэгдүүлэх;
# 4.2.2.барилгын болон хөгжлийн бэрхшээлтэй хүний асуудал эрхэлсэн
# 3асгийн газрын гишүүн, аймаг нийслэлийн 3асаг дарга нартай хамтран улс, орон
# нутгийн төсөв, бусад эх үүсвэрээс жил бүр тодорхой хөрөнгө гаргаж, ашиглалта0
# орсон боловч зах зээл дээр борлогдоогүй орон сууцнаас худалдан авах замаар орон
# нутгийн түрээсийн орон сууцны санг нэмэгдүүлэх;
# 4.2.3.шинээр ашиглалтад орж буй төрийн орон сууц бүрээс 27-37 мкв
# хүртэл байрыг хөгжлийн бэрхшээлтэй ирөдийн халамжийн орон сууц болгон тэдэнд
# хөнгөлөлттэй нөхцөлөөр худалдан авах боломжийг бүрдүүлэх;
# 4.2.4.ипотекийн зээлээр орон сууц худалдан авах урьдчилгаа
# төлбөрийн 10 хувийг хөгжлийн бэрхшээлтэй хүн өөрийн зардлаар, урьдчилгаа
# төлбөрийн зөрүүг орон сууцны тухай хуулийн 8.1.1-д заасны дагуу аймаг, дүүрпийн
# 3асаг даргын тухайн жилийн төсөвлөгдсөн хөрөнгөөс санхүүжүүлнэ.
# 4.3.Орон сууцны хөнгөлөлттэй зээлийн санхүүжилтийг зээлийн шаардпага
# хангасан хөгжлийн бэрхшээлтэй гишүүнтэй өрхөд дараалал харгаозахгүй олгох,
# 3ээлийн батлан даалтын сангаар баталюа гаргах асуудлыг байршил харгалзахгүй
# шийдвэрлэх зорилтын хүрээнд дараах үйл ажиллагавг хэрэгжүүлнэ:
# 4.3.1 .орон сууцны ипотекийн зээлд хамрагдах хүсэлт гаргасан
# хөгжлийн бэрхшээлтэй гишүүнтэй өрхийн зээлийн хүсэлтийг дараалал
# харгалзахгүйгээр зээлийн хорооны хурлаар хэлэлцүүлэх, шийдвэрлэгдсэн нөхцөлд
# зээлийн санхүүжилтээс тэргүүн ээлжид олгохыг эрэлхийлэх;
# 4.3.2.хөгжлийн бэрхшээлтэй гишүүнтэй өрх ипотекийн зээлээр
# дамжуулан худалдан авах орон сууцны урьдчилгаа төлбөрийн хэмжээнд 3ээлийн
# батлан даалтын сангаар баталгаа гаргуулах асуудлыг судалж шийдвэрлүүлэх.
# 4.4.Хөгжлийн бэрхшээлтэй иргэдийг ая тухтай амьдрах нөхцөлөөр хангах
# хүрээнд орон сууцны барилгыг хөгжлийн бэрхшээлтэй иргэдад хүртээмжтэй
# байдлаар төлөвлөнк ашиглалтад оруулах зорилтын хүрээнд дараах арга хэмжээг
# хэрэгжүүлнэ:
# 4.4.1.орон сууц, олон нийтийн барилю байгууламж, хот төлөвлөлтийн
# норм, нормативын баримт бичгийг хөгжлийн бэрхшээлтэй хүнд саадгүй болгон
# шинэчлэх;
# 4.4.2.зураг төсөл боловсруулах даалгаврыг захиалач хөгжлийн
# бэрхшээлтэй хүнд зориулсан хэрэгцээ, шаардлагыг заавал тусгуулан баталдаг
# тогтолцоог бүрдүүлэх;

# %% [markdown]
# # Mongolian OCR Service
#
# This service extracts text from Image and returns the extracted dext as a JSON response.
#
# ## Project Structure
# ```
# /project-root
# │── dataset/                        # Dataset for training character recognition model
# │   ├── chars_test.csv              # Test dataset
# │   ├── chars_train.csv             # Train dataset
# │── model/                          # Recognition model and Encoder
# │   ├── encoder.npy                 # Encoder
# │   ├── recognition_model.h5        # Trained character recognition model
# │── notebook/                       # General notebooks that is used to train and segment
# │   ├── demonstration.ipynb         # Demonstration of all process
# │   ├── train_recognition.ipynb     # Training recognition model
# │── src/                            # Source code for table extraction
# │   ├── adjust_height_width.py      # Resize image by finding median height and width of letters
# │   ├── post_process.py             # Post-process OCR raw result
# │   ├── recognition.py              # Recognition of letter and line
# │   ├── segmentation_character.py   # Segment characters from word
# │   ├── segmentation_contour.py     # Segment contours from input image
# │   ├── segmentation_line.py        # Segment lines from contour
# │   ├── segmentation_word.py        # Segment words from line
# │   ├── service.py                  # Main table extraction logic
# │   ├── skew_correction.py          # Correct skew angle of input image
# │   ├── utils.py                    # Utility functions
# │── test_imgs/                      # Images to test OCR service
# │   ├── img_001.jpg                 # Main table extraction logic
# │   ├── ...
# │── main.py                         # FastAPI application
# │── requirements.txt                # Dependencies
# │── Dockerfile                      # Docker configuration
# │── README.md                       # Documentation
# │── requist.ipynb                   # Example requist
# ```
#
# ## Setup Instructions
#
# ### 1. Clone the Repository
# ```sh
# git clone <repository-url>
# cd <repository-name>
# ```
#
# ### 2. Install Dependencies
# ```sh
# pip install -r requirements.txt
# ```
#
# ### 3. Run Locally
# ```sh
# uvicorn main:app --host 0.0.0.0 --port 8000
# ```
#
# ## Docker Setup
#
# ### 1. Build the Docker Image
# ```sh
# docker build --no-cache -t text-extraction .
# ```
#
# ### 2. Run the Container
# ```sh
# docker run -p 8000:8000 text-extraction
# ```
#
# ## API Endpoints
#
# ### Health Check
# ```http
# GET /health
# ```
# Response:
# ```json
# {"status": "ok"}
# ```
#
# ### Extract Text
# ```http
# POST /extract-text
# ```
# #### Request
# - **Content-Type:** multipart/form-image
# - **File:** JSON file containing image
#
# #### Response
# ```json
# {
#     "message": "Text extracted successfully",
#     "data": "4.2.Төрийн болон орон нутгийн өмчийн орон сууцны санг бүрдүүлж,..."
# }
# ```
