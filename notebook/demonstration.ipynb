# %%
import os, sys, cv2

os.chdir("..")
sys.path.insert(0, os.getcwd())

from src.service import extract_text
# Out:
# 2025-05-03 18:19:08.712332: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-03 18:19:08.713500: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-03 18:19:08.716677: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-03 18:19:08.726730: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
IMG_PATH = "test_imgs/img_001.jpg"
img = cv2.imread(IMG_PATH)
result = extract_text(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ...

# %%
print(result)
# Out:
# 4.2.Төрийн болон орон нутгийн өмчийн орон сууцны санг бүрдүүлж, тэргүүн
# ээлжид орон байргүй хөгжлийн бэрхшээлтэй гишүүнтэй өрхөд хөлслүүлэх,
# эзэмшүүлэх, төлбөрийн уян хатан, хөнгөлөлттэй нөхцөлөөр худалдан авах боломж
# бүрдүүлэх эорилтын хүрээнд дараах үйл ажиллагааг хэрэгжүүлнэ:
# 4.2.1.аймаг, нийслэлийн 3асаг дарга нь орон сууц барих аж ахуйн
# нэгжтэй тохиролцон шинээр баригдах орон сууцны газар, дэд бүтцэд улс, орон
# нутгийн төсвөөс оруулсан хөрөнгө оруулалттай дүйцүүлэн, тодорхой хувьд ны орон
# сууцыг гэрээний дагуу эээмшилдээ авах замаар орон нуттийн түрээсийв орон
# сууцны санг бүрдүүлэх, нэмэгдүүлэх;
# 4.2.2.барилгын болон хөгжлийн бэрхшээлтэй хүний асуудал эрхэлсэн
# 3асгийн газрын гишүүн, аймаг нийслэлийн 3асаг дарга нартай хамтран улс, орон
# нутгийн төсөв, бусад эх үүсвэрээс жил бүр тодорхой хөрөнгө гаргаж, ашиглалта0
# орсон боловч зах зээл дээр борлогдоогүй орон сууцнаас худалдан авах замаар орон
# нутгийн түрээсийн орон сууцны санг нэмэгдүүлэх;
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import cv2

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(18, 8))
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1.2])

ax0 = plt.subplot(gs[0])
ax0.imshow(img)
ax0.axis("on")
ax0.set_title("Input Image", fontsize=16, loc="left")

ax1 = plt.subplot(gs[1])
ax1.axis("off")
ax1.set_title("Recognized Text", fontsize=16, loc="left")
ax1.text(0, 1, result, fontsize=10, wrap=True, va='top', ha='left', transform=ax1.transAxes)

plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, wspace=0.2)
plt.show()
